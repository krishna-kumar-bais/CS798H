# %%
import pandas as pd

# Load the dataset
file_path = "/uber_reviews_without_reviewid.csv"  # Replace with your actual file path
df = pd.read_csv(file_path)

# Define location-related keywords
location_keywords = [
    "hospital", "airport", "railway", "flight",
    "train", "train station", "emergency"
]

# Filter reviews mentioning any of these keywords
filtered_reviews = df[
    df["content"].str.contains(r'\b(?:' + '|'.join(location_keywords) + r')\b', case=False, na=False)
]

# Save to a new Excel file
output_file = "filtered_reviews.xlsx"
filtered_reviews.to_excel(output_file, index=False, engine='openpyxl')

print(f"Filtered reviews saved to {output_file}")

# %% [markdown]
# # Data / Documents

# %% [markdown]
# Surveys Google Forms [**link**](https://docs.google.com/forms/d/e/1FAIpQLScH5WJapm-Bojp-Qn3faSdVuSKrcuMQtyFRsBBqKiqtggzdfg/viewform?usp=header)

# %% [markdown]
#  Google Form Survey Responses [**link**](https://docs.google.com/spreadsheets/d/10gzXrCzWUVPKuCt3um_RMPOhsNpyzz0L/edit?gid=806055795#gid=806055795)

# %% [markdown]
# Kaggle Uber Customer Reviews Dataset (2024) [link](https://www.kaggle.com/datasets/kanchana1990/uber-customer-reviews-dataset-2024?resource=download)

# %% [markdown]
# Kaggle Uber Customer Reviews Dataset(2024) (filtered) [link](https://docs.google.com/spreadsheets/d/1XSt5SM4NY_xcpCmoircPg70wAfPCEtkc/edit?gid=443694618#gid=443694618)
